# %%
# ! pip install folium
# ! pip install googlemaps

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import folium
from folium import plugins
import re
import googlemaps
import pprint

# %% [markdown]
# # googlemaps

# %%
gmaps = googlemaps.Client(key='AIzaSyCQWM6dFymuis1oh9DelTIPFO1igh1nVuo')

# %% [markdown]
# ## marker

# %%
map = folium.Map(location=[37.5666805, 126.9784147], zoom_start=15, tiles='OpenStreetMap')


tooltip = "Click me!"

folium.Marker(
    [37.5666805, 126.9784147], popup="<i>시청</i>", tooltip=tooltip,
        icon=folium.Icon(color="red", icon="info-sign")
).add_to(map)

folium.CircleMarker(
    location=[37.5666805, 126.9784147],
    radius=100,
    popup="시청",
    color="#3186cc",
    fill=True,
    fill_color="#3186cc",
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## MarkerCluster

# %%
N = 50

lat_list =np.random.uniform(low =36, high =38,size = N)
lng_list =np.random.uniform(low =127, high =129,size = N)

map = folium.Map(location=[37.5666805, 126.9784147], zoom_start=8, tiles='OpenStreetMap')

geo_list = []
for i , lat in enumerate(lat_list):
    geo_list.append((lat_list[i], lng_list[i]))


geo_list[:5]

name_list = []
for i in range(N):
    name_list.append('빵집' + str([i]))

plugins.MarkerCluster(geo_list, popups = name_list).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from folium.plugins import MarkerCluster

usmap = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(usmap)


folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

usmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Google map

# %% [markdown]
# ## 주소 >> 위/경도

# %%
geocode_result = gmaps.geocode(('제주국제공항'), language='ko')
# pprint.pprint(geocode_result)

addr1 =geocode_result[0]['formatted_address']
lat1 =geocode_result[0]['geometry']['location']['lat']
lng1 =geocode_result[0]['geometry']['location']['lng']

print('주소 : ', geocode_result[0]['formatted_address'])
print('위도 : ',geocode_result[0]['geometry']['location']['lat'])
print('경도 : ',geocode_result[0]['geometry']['location']['lng'])
# Out:
# 주소 :  대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU)
# 위도 :  33.51041350000001
# 경도 :  126.4913534

# %% [markdown]
# ## 위/경도 >>주소

# %% [markdown]
# * reverse_geocode((위도, 경도))

# %%
rg_res=gmaps.reverse_geocode((lat1, lng1), language = 'ko')
rg_res


for i in range(len(rg_res)):
    lng = rg_res[i]['geometry']['location']['lng']
    lat = rg_res[i]['geometry']['location']['lat']
    addr = rg_res[i]['formatted_address']
    if len(addr.split())> 3:
        print(addr, lat, lng)
# Out:
# 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU) 33.51041350000001 126.4913534
# 대한민국 제주특별자치도 제주시 용담이동 833 33.5087187 126.4895311
# 대한민국 제주특별자치도 제주시 서해안로 33.5110314 126.4802212
# 대한민국 제주특별자치도 제주시 용담2동 33.5305996 126.4905278
# 대한민국 제주특별자치도 제주시 용담이동 33.5055121 126.4976769

# %%
for i in range(len(rg_res)):
    addr = rg_res[i]['formatted_address']
    check = re.match('대한민국[\w\s]*', addr)
    d_addr = len(addr.split())
    if check and d_addr > 3:
        lat  = rg_res[i]['geometry']['location']['lat']
        lng  = rg_res[i]['geometry']['location']['lng']
        print(addr, lat, lng)
# Out:
# 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU) 33.51041350000001 126.4913534
# 대한민국 제주특별자치도 제주시 용담이동 833 33.5087187 126.4895311
# 대한민국 제주특별자치도 제주시 서해안로 33.5110314 126.4802212
# 대한민국 제주특별자치도 제주시 용담2동 33.5305996 126.4905278
# 대한민국 제주특별자치도 제주시 용담이동 33.5055121 126.4976769

# %%
# lng2 = rmap[2]['geometry']['location']['lng']
# lat2 = rmap[2]['geometry']['location']['lat']
# addr2 = rmap[2]['formatted_address']

# lng3 = rmap[3]['geometry']['location']['lng']
# lat3 = rmap[3]['geometry']['location']['lat']
# addr3 = rmap[3]['formatted_address']

# lng4 = rmap[4]['geometry']['location']['lng']
# lat4 = rmap[4]['geometry']['location']['lat']
# addr4 = rmap[4]['formatted_address']

# lng5 = rmap[5]['geometry']['location']['lng']
# lat5 = rmap[5]['geometry']['location']['lat']
# addr5 = rmap[5]['formatted_address']

# lng6 = rmap[6]['geometry']['location']['lng']
# lat6 = rmap[6]['geometry']['location']['lat']
# addr6 = rmap[6]['formatted_address']

# lng7 = rmap[7]['geometry']['location']['lng']
# lat7 = rmap[7]['geometry']['location']['lat']
# addr7 = rmap[7]['formatted_address']

# lng8 = rmap[8]['geometry']['location']['lng']
# lat8 = rmap[8]['geometry']['location']['lat']
# addr8 = rmap[8]['formatted_address']

# %%
# print(addr1,lat1,lng1, '|n',
#       addr2,lat2,lng2, '|n',
#       addr3,lat3,lng3, '|n',
#       addr4,lat4,lng4, '|n',
#       addr5,lat5,lng5, '|n',
#       addr6,lat6,lng6, '|n',
#       addr7,lat7,lng7, '|n',
#       addr8,lat8,lng8, '|n'
     # )

# %% [markdown]
# # csv Data Load
# * [공공데이터포털]'제주관광공사_제주관광정보시스템(VISIT JEJU)_여행장소_20220322.csv'
#     * ref : https://www.data.go.kr/data/15049995/fileData.do?recommendDataYn=Y

# %%
df = pd.read_csv('제주관광공사_제주관광정보시스템(VISIT JEJU)_여행장소_20220322.csv', encoding = 'cp949')
df2=df[df['장소상세설명']=='숙소']
df2.head()
# Out:
#      장소ID       장소명                                도로명주소 장소상세설명         위도  \
# 15    313  비스타케이월드컵  제주특별자치도 서귀포시 김정문화로41번길 10-6 비스타케이호텔     숙소  33.251932
# 116   387   제주한화리조트        제주특별자치도 제주시 명림로 575-107 한화리조트     숙소  33.448300
# 117   390   비스타케이호텔              제주특별자치도 서귀포시 중산간동로 7965     숙소  33.278516
# 128   400      토끼굴                제주특별자치도 제주시 한동북1길 9-14     숙소  33.540343
# 131   403    한동올레펜션              제주특별자치도 제주시 한동로4길 20-16     숙소  33.535637
#
#              경도        등록일시        수정일시                      지번주소 사용여부
# 15   126.509770  2018-06-01  2018-06-01    제주특별자치도 서귀포시 대륜동 745-1    y
# 116  126.637662  2018-06-16  2018-06-16      제주특별자치도 제주시 봉개동 3-16    y
# 117  126.527528  2018-06-17  2018-06-17     제주특별자치도 서귀포시 대륜동 2126    y
# 128  126.826223  2018-06-18  2018-06-18  제주특별자치도 제주시 구좌읍 한동리 1502    y
# 131  126.821156  2018-06-18  2018-06-18  제주특별자치도 제주시 구좌읍 한동리 1891    y

# %%
# jmap = folium.Map(location=[33.51041350000001, 126.4913534], zoom_start=8, tiles='OpenStreetMap')
# geo_list = []
# for i,lat  in enumerate(df['위도']):
#     geo_list.append((df['위도'][i], df['경도'][i]))


# name_list = []
# for nm in df['장소명']:
#     name_list.append(nm)
    

# plugins.MarkerCluster(geo_list, popups = name_list).add_to(jmap)
# jmap

# %%
jmap = folium.Map(location=[33.51041350000001, 126.4913534], zoom_start=8, tiles='OpenStreetMap')


geo_list = []
for i  in df2.index:
        geo_list.append((df2['위도'][i], df2['경도'][i]))


name_list = []
for nm in df2['장소명']:
    name_list.append(nm)
    

plugins.MarkerCluster(geo_list, popups = name_list).add_to(jmap)
jmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
type(df['위도'])
# Out:
# pandas.core.series.Series
