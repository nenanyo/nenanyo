# %% [markdown]
# # word cloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
import sqlalchemy as sa
import cx_Oracle
import xml.etree.ElementTree as ET
import json
import requests
from bs4 import BeautifulSoup


import pandas as pd
import time
import datetime
import random
# random.uniform(0.2, 1.2)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.text import text_to_word_sequence
from nltk.tokenize import word_tokenize
from collections import Counter

# %%
df = pd.read_csv("./datasets/joong1.csv")
df.head()
# Out:
#                                                title  \
# 0  Major Korean financial holding firms beat mark...
# 1              K-eco helps with carbon neutral goals
# 2  LG Household & Health Care reports 96.3 billio...
# 3  FTC conditionally approves Hanwha acquisition ...
# 4  Travel demand high in Korea ahead of long week...
#
#                                                  url  \
# 0  https://koreajoongangdaily.joins.com/2023/04/2...
# 1  https://koreajoongangdaily.joins.com/2023/04/2...
# 2  https://koreajoongangdaily.joins.com/2023/04/2...
# 3  https://koreajoongangdaily.joins.com/2023/04/2...
# 4  https://koreajoongangdaily.joins.com/2023/04/2...
#
#                                              content
# 0  Four major financial holding firms beat the ma...
# 1  The Korea Environment Cooperation (K-eco) is c...
# 2  LG Household & Health Care reported a lower-th...
# 3  Korea's antitrust regulator approved the acqui...
# 4  The pent-up travel demand is pouring out in la...

# %% [markdown]
# ## 워드 클라우드

# %%
def my_cloud_chart(prm):
    wc = WordCloud(font_path='C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7fBOLD.TTF'
                   ,background_color="white", max_font_size=60)
    
    try : 
        if type(prm) == str:
            cloud = wc.generate(prm)
        else :
            cloud = wc.generate_from_frequencies(dict(prm))

        # cloud.to_file('test.jpg')

        plt.figure(figsize=(5, 3))
        plt.axis('off')
        plt.imshow(cloud)
        plt.show()
    except:
        print("파라미터는 str 또는 dict만 지원합니다")

# %%
text = " ".join(df['content'])
# text

# %%
my_cloud_chart(text)
